# %% [markdown]
# # Comparison
#
# In this notebook, we'll do analysis between Zika spread and rainfall for Argentina.

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import geopandas as gpd
import descartes

from shapely.geometry import Point

# %% [markdown]
# ## April 2016 analysis
#
# Let's try to analyse the data for April 2016.

# %% [markdown]
# I'll load in the data files.

# %%
dataset = pd.read_csv("zika_data/2016-04.csv")
places = pd.read_csv("zika_data/places.csv")
march_2016_data = pd.read_csv("data/precipitation_4_2016.csv")

# %% [markdown]
# Update the data frame to reflect location and names.

# %%
final_df = pd.merge(dataset, places, how = 'inner', left_on = "location", right_on = "location")
final_df = final_df[["location", "value", "latitude", "longitude"]].groupby(["location", "latitude", "longitude"]).sum().reset_index()

# %% [markdown]
# Plot the rainfall and Zika data.

# %%
world = gpd.read_file("shapefiles/provinces/ARG_adm1.shp")

ax = world.plot(color = 'lightgrey', linewidth = 0.5, edgecolor = 'black', figsize = (20, 12))

points = [Point(xy) for xy in zip(march_2016_data["longitude"], march_2016_data["latitude"])]
geo_df = gpd.GeoDataFrame(march_2016_data, crs = {'init': 'epsg:4326'}, geometry = points)
geo_df.plot(column = 'precipitation', 
            markersize = 1, 
            ax = ax, 
            legend = True, 
            cmap = 'YlOrRd', 
            vmin = 0.0, 
            vmax = 0.7)

points2 = [Point(xy) for xy in zip(final_df["longitude"], final_df["latitude"])]
zika_df = gpd.GeoDataFrame(final_df, crs = {'init': 'epsg:4326'}, geometry = points2)
zika_df.plot(column = 'value', ax = ax, markersize = 'value', color = 'blue')
plt.title("Average rainfall (mm/hr) for April, 2016")

ax.axis('off')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/geopandas/plotting.py:471: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   "Only specify one of 'column' or 'color'. Using 'color'.", UserWarning
# (-74.57737693511623,
#  -52.592523502299095,
#  -56.743037316433366,
#  -20.11357157129934)

# %% [markdown]
# ## September 2016 analysis
#
# The same analysis can be done for September 2016 too.

# %%
dataset = pd.read_csv("zika_data/2016-09.csv")
places = pd.read_csv("zika_data/places.csv")
march_2016_data = pd.read_csv("data/precipitation_9_2016.csv")

final_df = pd.merge(dataset, places, how = 'inner', left_on = "location", right_on = "location")
final_df = final_df[["location", "value", "latitude", "longitude"]].groupby(["location", "latitude", "longitude"]).sum().reset_index()


world = gpd.read_file("shapefiles/provinces/ARG_adm1.shp")

ax = world.plot(color = 'lightgrey', linewidth = 0.5, edgecolor = 'black', figsize = (20, 12))

points = [Point(xy) for xy in zip(march_2016_data["longitude"], march_2016_data["latitude"])]
geo_df = gpd.GeoDataFrame(march_2016_data, crs = {'init': 'epsg:4326'}, geometry = points)
geo_df.plot(column = 'precipitation', 
            markersize = 1, 
            ax = ax, 
            legend = True, 
            cmap = 'YlOrRd', 
            vmin = 0.0, 
            vmax = 0.7)

points2 = [Point(xy) for xy in zip(final_df["longitude"], final_df["latitude"])]
zika_df = gpd.GeoDataFrame(final_df, crs = {'init': 'epsg:4326'}, geometry = points2)
zika_df.plot(column = 'value', ax = ax, markersize = 'value', color = 'blue')
plt.title("Average rainfall (mm/hr) for September, 2016")

ax.axis('off')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/geopandas/plotting.py:471: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   "Only specify one of 'column' or 'color'. Using 'color'.", UserWarning
# (-74.57737693511623,
#  -52.592523502299095,
#  -56.743037316433366,
#  -20.11357157129934)

# %% [markdown]
# ## February 2017 analysis
#
# The same analysis can be done for February 2017 too.

# %%
dataset = pd.read_csv("zika_data/2017-02.csv")
places = pd.read_csv("zika_data/places.csv")
march_2016_data = pd.read_csv("data/precipitation_2_2017.csv")

final_df = pd.merge(dataset, places, how = 'inner', left_on = "location", right_on = "location")
final_df = final_df[["location", "value", "latitude", "longitude"]].groupby(["location", "latitude", "longitude"]).sum().reset_index()


world = gpd.read_file("shapefiles/provinces/ARG_adm1.shp")

ax = world.plot(color = 'lightgrey', linewidth = 0.5, edgecolor = 'black', figsize = (20, 12))

points = [Point(xy) for xy in zip(march_2016_data["longitude"], march_2016_data["latitude"])]
geo_df = gpd.GeoDataFrame(march_2016_data, crs = {'init': 'epsg:4326'}, geometry = points)
geo_df.plot(column = 'precipitation', 
            markersize = 1, 
            ax = ax, 
            legend = True, 
            cmap = 'YlOrRd', 
            vmin = 0.0, 
            vmax = 0.7)

points2 = [Point(xy) for xy in zip(final_df["longitude"], final_df["latitude"])]
zika_df = gpd.GeoDataFrame(final_df, crs = {'init': 'epsg:4326'}, geometry = points2)
zika_df.plot(column = 'value', ax = ax, markersize = 'value', color = 'blue')
plt.title("Average rainfall (mm/hr) for February, 2017")

ax.axis('off')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/geopandas/plotting.py:471: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   "Only specify one of 'column' or 'color'. Using 'color'.", UserWarning
# (-74.57737693511623,
#  -52.592523502299095,
#  -56.743037316433366,
#  -20.11357157129934)
